# %%
# Import libraries
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.safari.service import Service
from bs4 import BeautifulSoup
import pandas as pd
import time

# %% [markdown]
# **TLDR solution:**
# 1. Using the URL provided and the year in the prompt, we get the first HTML page for scraping. This implementation is handled in _getfirstpagehtml_
# 2. For the page, we scrape all the research paper links (20 at a time) and save them in a csv along with their metadata link, which can be constructed with slight modification and has "?show=full" at the end. This is handled in _getlinksfromhtml_
# 3. Finally, we move on to the next page, and repeat step 2. This implementation is handled in _scrapemetadatalinks_
#
# This design gives flexibility to the user and allows to pressure test implementation piece by piece. Further, by downloading links page by page, which can always be aggregated later, we can isolate manual checks on certain pages too.

# %%
# Function to initialize the Selenium WebDriver
def init_driver():
    service = Service()
    driver = webdriver.Safari(service=service)
    return driver

# Function to get the first page of the research papers
def get_first_page_html(driver, url, year):
    # Construct the URL with the year parameter
    params = {
        'type': 'dateissued',
        'sort_by': '2',
        'order': 'ASC',
        'rpp': '20',  # Number of results per page
        'starts_with': str(year)
    }
    
    # Perform the navigation with the constructed URL and parameters
    full_url = url + '?' + '&'.join([f'{k}={v}' for k, v in params.items()])
    driver.get(full_url)
    return driver.page_source

# %%
# Function to extract links from the main page

def get_links_from_html(html, page_number):
    soup = BeautifulSoup(html, 'html.parser')
    existing_links = set()
    paper_links = []

    # Locate the specific <div> containing the <ul> with the links
    container_div = soup.find('div', id='aspect_artifactbrowser_ConfigurableBrowse_div_browse-by-dateissued-results', class_='ds-static-div primary')
    if container_div:
        artifact_list = container_div.find('ul', class_='ds-artifact-list list-unstyled')
        if artifact_list:
            for link in artifact_list.select('a[href^="/handle/1721.1/"]'):
                href = 'https://dspace.mit.edu' + link['href']
                metadata_link = href + '?show=full'
                if href not in existing_links:
                    paper_links.append({'href': href, 'page_number': page_number, 'metadata_link': metadata_link})
                    existing_links.add(href)
    
    return existing_links, paper_links

# %%
# Function to combine everything and scrape the metadata links

def scrape_metadata_links(url, year):
    driver = init_driver()
    page_number = 1
    current_page_url = url

    while True:
        # Get the current page's HTML
        page_html = get_first_page_html(driver, current_page_url, year)
        print(f"Extracting links from page {page_number}...")
        
        _, paper_links = get_links_from_html(page_html, page_number)
        
        # Export the links to a CSV for the current page
        df = pd.DataFrame(paper_links)
        df.to_csv(f'research_paper_links_page_{page_number}.csv', index=False)
        print(f"Saved page {page_number} links to research_paper_links_page_{page_number}.csv")
        
        # Find the next page link using pagination info
        soup = BeautifulSoup(page_html, 'html.parser')
        pagination_info = soup.find('p', class_='pagination-info').text
        next_offset = int(pagination_info.split(' ')[3].split('-')[1].strip('"'))
        print(f"Next offset: {next_offset}")
        total_items = int(pagination_info.split(' ')[5])
        print(f"Total items: {total_items}")
        
        if next_offset >= total_items:
            break
        
        results_per_page = 20
        current_page_url = f'https://dspace.mit.edu/handle/1721.1/5458/browse?rpp={results_per_page}&offset={next_offset}&etal=-1&sort_by=2&type=dateissued&starts_with={year}&order=ASC'
        driver.get(current_page_url)
        time.sleep(5)  # Adjust the delay as needed
        
        page_number += 1
    
    driver.quit()
    return page_number - 1

# %%
# Executing the pipeline
url = 'https://dspace.mit.edu/handle/1721.1/5458/browse'
year = 2000
num_pages = scrape_metadata_links(url, year)
print(f"Extracted and saved links from {num_pages} pages.")
# Out:
# Extracting links from page 1...
# Saved page 1 links to research_paper_links_page_1.csv
# Next offset: 2727
# Total items: 3804
# Extracting links from page 2...
# Saved page 2 links to research_paper_links_page_2.csv
# Next offset: 2747
# Total items: 3804
# Extracting links from page 3...
# Saved page 3 links to research_paper_links_page_3.csv
# Next offset: 2767
# Total items: 3804
# Extracting links from page 4...
# Saved page 4 links to research_paper_links_page_4.csv
# Next offset: 2787
# Total items: 3804
# Extracting links from page 5...
# Saved page 5 links to research_paper_links_page_5.csv
# Next offset: 2807
# Total items: 3804
# Extracting links from page 6...
# Saved page 6 links to research_paper_links_page_6.csv
# Next offset: 2827
# Total items: 3804
# Extracting links from page 7...
# Saved page 7 links to research_paper_links_page_7.csv
# Next offset: 2847
# Total items: 3804
# Extracting links from page 8...
# Saved page 8 links to research_paper_links_page_8.csv
# Next offset: 2867
# Total items: 3804
# Extracting links from page 9...
# Saved page 9 links to research_paper_links_page_9.csv
# Next offset: 2887
# Total items: 3804
# Extracting links from page 10...
# Saved page 10 links to research_paper_links_page_10.csv
# Next offset: 2907
# Total items: 3804
# Extracting links from page 11...
# Saved page 11 links to research_paper_links_page_11.csv
# Next offset: 2927
# Total items: 3804
# Extracting links from page 12...
# Saved page 12 links to research_paper_links_page_12.csv
# Next offset: 2947
# Total items: 3804
# Extracting links from page 13...
# Saved page 13 links to research_paper_links_page_13.csv
# Next offset: 2967
# Total items: 3804
# Extracting links from page 14...
# Saved page 14 links to research_paper_links_page_14.csv
# Next offset: 2987
# Total items: 3804
# Extracting links from page 15...
# Saved page 15 links to research_paper_links_page_15.csv
# Next offset: 3007
# Total items: 3804
# Extracting links from page 16...
# Saved page 16 links to research_paper_links_page_16.csv
# Next offset: 3027
# Total items: 3804
# Extracting links from page 17...
# Saved page 17 links to research_paper_links_page_17.csv
# Next offset: 3047
# Total items: 3804
# Extracting links from page 18...
# Saved page 18 links to research_paper_links_page_18.csv
# Next offset: 3067
# Total items: 3804
# Extracting links from page 19...
# Saved page 19 links to research_paper_links_page_19.csv
# Next offset: 3087
# Total items: 3804
# Extracting links from page 20...
# Saved page 20 links to research_paper_links_page_20.csv
# Next offset: 3107
# Total items: 3804
# Extracting links from page 21...
# Saved page 21 links to research_paper_links_page_21.csv
# Next offset: 3127
# Total items: 3804
# Extracting links from page 22...
# Saved page 22 links to research_paper_links_page_22.csv
# Next offset: 3147
# Total items: 3804
# Extracting links from page 23...
# Saved page 23 links to research_paper_links_page_23.csv
# Next offset: 3167
# Total items: 3804
# Extracting links from page 24...
# Saved page 24 links to research_paper_links_page_24.csv
# Next offset: 3187
# Total items: 3804
# Extracting links from page 25...
# Saved page 25 links to research_paper_links_page_25.csv
# Next offset: 3207
# Total items: 3804
# Extracting links from page 26...
# Saved page 26 links to research_paper_links_page_26.csv
# Next offset: 3227
# Total items: 3804
# Extracting links from page 27...
# Saved page 27 links to research_paper_links_page_27.csv
# Next offset: 3247
# Total items: 3804
# Extracting links from page 28...
# Saved page 28 links to research_paper_links_page_28.csv
# Next offset: 3267
# Total items: 3804
# Extracting links from page 29...
# Saved page 29 links to research_paper_links_page_29.csv
# Next offset: 3287
# Total items: 3804
# Extracting links from page 30...
# Saved page 30 links to research_paper_links_page_30.csv
# Next offset: 3307
# Total items: 3804
# Extracting links from page 31...
# Saved page 31 links to research_paper_links_page_31.csv
# Next offset: 3327
# Total items: 3804
# Extracting links from page 32...
# Saved page 32 links to research_paper_links_page_32.csv
# Next offset: 3347
# Total items: 3804
# Extracting links from page 33...
# Saved page 33 links to research_paper_links_page_33.csv
# Next offset: 3367
# Total items: 3804
# Extracting links from page 34...
# Saved page 34 links to research_paper_links_page_34.csv
# Next offset: 3387
# Total items: 3804
# Extracting links from page 35...
# Saved page 35 links to research_paper_links_page_35.csv
# Next offset: 3407
# Total items: 3804
# Extracting links from page 36...
# Saved page 36 links to research_paper_links_page_36.csv
# Next offset: 3427
# Total items: 3804
# Extracting links from page 37...
# Saved page 37 links to research_paper_links_page_37.csv
# Next offset: 3447
# Total items: 3804
# Extracting links from page 38...
# Saved page 38 links to research_paper_links_page_38.csv
# Next offset: 3467
# Total items: 3804
# Extracting links from page 39...
# Saved page 39 links to research_paper_links_page_39.csv
# Next offset: 3487
# Total items: 3804
# Extracting links from page 40...
# Saved page 40 links to research_paper_links_page_40.csv
# Next offset: 3507
# Total items: 3804
# Extracting links from page 41...
# Saved page 41 links to research_paper_links_page_41.csv
# Next offset: 3527
# Total items: 3804
# Extracting links from page 42...
# Saved page 42 links to research_paper_links_page_42.csv
# Next offset: 3547
# Total items: 3804
# Extracting links from page 43...
# Saved page 43 links to research_paper_links_page_43.csv
# Next offset: 3567
# Total items: 3804
# Extracting links from page 44...
# Saved page 44 links to research_paper_links_page_44.csv
# Next offset: 3587
# Total items: 3804
# Extracting links from page 45...
# Saved page 45 links to research_paper_links_page_45.csv
# Next offset: 3607
# Total items: 3804
# Extracting links from page 46...
# Saved page 46 links to research_paper_links_page_46.csv
# Next offset: 3627
# Total items: 3804
# Extracting links from page 47...
# Saved page 47 links to research_paper_links_page_47.csv
# Next offset: 3647
# Total items: 3804
# Extracting links from page 48...
# Saved page 48 links to research_paper_links_page_48.csv
# Next offset: 3667
# Total items: 3804
# Extracting links from page 49...
# Saved page 49 links to research_paper_links_page_49.csv
# Next offset: 3687
# Total items: 3804
# Extracting links from page 50...
# Saved page 50 links to research_paper_links_page_50.csv
# Next offset: 3707
# Total items: 3804
# Extracting links from page 51...
# Saved page 51 links to research_paper_links_page_51.csv
# Next offset: 3727
# Total items: 3804
# Extracting links from page 52...
# Saved page 52 links to research_paper_links_page_52.csv
# Next offset: 3747
# Total items: 3804
# Extracting links from page 53...
# Saved page 53 links to research_paper_links_page_53.csv
# Next offset: 3767
# Total items: 3804
# Extracting links from page 54...
# Saved page 54 links to research_paper_links_page_54.csv
# Next offset: 3787
# Total items: 3804
# Extracting links from page 55...
# Saved page 55 links to research_paper_links_page_55.csv
# Next offset: 3804
# Total items: 3804
# Extracted and saved links from 54 pages.
